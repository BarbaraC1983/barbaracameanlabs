# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %%
## Initialize Spotify with user credentials
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import config
import pandas as pd

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.c_id, client_secret=config.c_se))

# %%
## Function to use the downloaded documents
def load(filename = "filename.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!")

# %% [markdown]
# # Setting everything for running the model

# %% [markdown]
# # Spotify API

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.c_id, client_secret=config.c_se))

# %%
# Get the hotlist from the first document
hotlist = pd.read_csv('hot_list.csv')
hotlist
# Out:
#     Unnamed: 0                      title  \
# 0            0  We Don't Talk About Bruno
# 1            1      Do We Have A Problem?
# 2            2                 Easy On Me
# 3            3                 Heat Waves
# 4            4                       Stay
# ..         ...                        ...
# 95          95                       Iffy
# 96          96              When I'm Gone
# 97          97                 Fair Trade
# 98          98              Megan's Piano
# 99          99            Moth To A Flame
#
#                                           artist_name
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...
# 1                              Nicki Minaj X Lil Baby
# 2                                               Adele
# 3                                       Glass Animals
# 4                       The Kid LAROI & Justin Bieber
# ..                                                ...
# 95                                        Chris Brown
# 96                                Alesso / Katy Perry
# 97                       Drake Featuring Travis Scott
# 98                                Megan Thee Stallion
# 99                   Swedish House Mafia & The Weeknd
#
# [100 rows x 3 columns]

# %% [markdown]
# # Function to get user input

# %%
## Get user input 
song_input = input("Please enter a name of a song:")
if song_input in hotlist.values:
    print("See other recommended song:")
    print(hotlist.sample())
else:
    print("Unfortunately, the song is not in the hot list!")
# Out:
# Please enter a name of a song:We Don't Talk About Bruno
# See other recommended song:
#    Unnamed: 0          title  artist_name
# 5           5  Super Gremlin  Kodak Black

# %% [markdown]
# # Getting the features of the imput song

# %%
song_input = sp.search(q = song_input, limit = 1 , market ="GB")
song_input
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=tracks&type=track&market=GB&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TKOZZDd5uV5KnyC5G4MUt'},
#        'href': 'https://api.spotify.com/v1/artists/6TKOZZDd5uV5KnyC5G4MUt',
#        'id': '6TKOZZDd5uV5KnyC5G4MUt',
#        'name': 'Smokey Robinson & The Miracles',
#        'type': 'artist',
#        'uri': 'spotify:artist:6TKOZZDd5uV5KnyC5G4MUt'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2NT1Pc0MXlXORHLBkHyKQW'},
#      'href': 'https://api.spotify.com/v1/albums/2NT1Pc0MXlXORHLBkHyKQW',
#      'id': '2NT1Pc0MXlXORHLBkHyKQW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27396ebd8447b29307e31f95090',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0296ebd8447b29307e31f95090',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485196ebd8447b29307e31f95090',
#        'width': 64}],
#      'name': 'Going To A Go-Go',
#      'release_date': '1965-11-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2NT1Pc0MXlXORHLBkHyKQW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TKOZZDd5uV5KnyC5G4MUt'},
#       'href': 'https://api.spotify.com/v1/artists/6TKOZZDd5uV5KnyC5G4MUt',
#       'id': '6TKOZZDd5uV5KnyC5G4MUt',
#       'name': 'Smokey Robinson & The Miracles',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TKOZZDd5uV5KnyC5G4MUt'}],
#     'disc_number': 1,
#     'duration_ms': 174360,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMO16500449'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6QyQmdvQ1ywNccYa0pwLNQ'},
#     'href': 'https://api.spotify.com/v1/tracks/6QyQmdvQ1ywNccYa0pwLNQ',
#     'id': '6QyQmdvQ1ywNccYa0pwLNQ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The Tracks Of My Tears',
#     'popularity': 67,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6QyQmdvQ1ywNccYa0pwLNQ'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=tracks&type=track&market=GB&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 10015}}

# %%
song_input['tracks']['items'][0]['id']
# Out:
# '6QyQmdvQ1ywNccYa0pwLNQ'

# %%
input_song_features = sp.audio_features(song_input['tracks']['items'][0]['id'])
input_song_features
# Out:
# [{'danceability': 0.502,
#   'energy': 0.333,
#   'key': 7,
#   'loudness': -10.914,
#   'mode': 1,
#   'speechiness': 0.0264,
#   'acousticness': 0.699,
#   'instrumentalness': 0,
#   'liveness': 0.222,
#   'valence': 0.729,
#   'tempo': 96.982,
#   'type': 'audio_features',
#   'id': '6QyQmdvQ1ywNccYa0pwLNQ',
#   'uri': 'spotify:track:6QyQmdvQ1ywNccYa0pwLNQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6QyQmdvQ1ywNccYa0pwLNQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6QyQmdvQ1ywNccYa0pwLNQ',
#   'duration_ms': 174360,
#   'time_signature': 4}]

# %%
## Get only the numerical data There are colums that are categorical which are not needed
input_song_features = pd.DataFrame(input_song_features)
input_song_features_num = input_song_features._get_numeric_data()

# %%
## Drop the columns which are not needed
input_song_features_num = input_song_features_num.drop(columns=["key","mode","time_signature"])
input_song_features_num
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.502   0.333   -10.914       0.0264         0.699
#
#    instrumentalness  liveness  valence   tempo  duration_ms
# 0                 0     0.222    0.729  96.982       174360

# %%
model = load("scaler.pickle")

# %%
## Scale the numerical features
input_song_scaled = model.transform(input_song_features_num)

# %%
## We use the same features as the one with had with the list of tracks from Spotify
input_song_scaled = pd.DataFrame(input_song_scaled, columns = ["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness",
                          "valence", "tempo", "duration_ms"])
input_song_scaled
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.908543 -0.923834 -0.265143    -0.710312      1.089329
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.492715  0.418221  0.941212 -0.785425    -0.416092

# %%
model_kmeans = load("kmeans_4.pickle")

# %%
## Check to which cluster belongs the track
input_song_cluster = model_kmeans.predict(input_song_scaled)

# %%
input_song_cluster
# Out:
# array([6], dtype=int32)

# %%
model_kmeans
# Out:
# KMeans(random_state=1234)

# %%
## Get the table from the clustering notebook. Here are the features of the spotify track list
cluster_id = pd.read_csv('cluster_id.csv')
cluster_id
# Out:
#       Unnamed: 0  danceability  energy  loudness  speechiness  acousticness  \
# 0              0         0.918   0.609    -5.640       0.0791       0.09280
# 1              1         0.899   0.713    -2.752       0.3660       0.25500
# 2              2         0.957   0.737    -4.880       0.1150       0.21000
# 3              3         0.664   0.758    -6.583       0.2100       0.00238
# 4              4         0.768   0.864    -6.145       0.0324       0.10100
# ...          ...           ...     ...       ...          ...           ...
# 5083        5083         0.651   0.801    -7.340       0.0514       0.12300
# 5084        5084         0.543   0.529    -9.717       0.0301       0.32600
# 5085        5085         0.468   0.607   -11.367       0.0336       0.07200
# 5086        5086         0.299   0.787    -7.930       0.0690       0.14000
# 5087        5087         0.413   0.725    -5.787       0.0324       0.36900
#
#       instrumentalness  liveness  valence    tempo  ...  tempo.1  \
# 0             0.000000    0.1390    0.304  128.008  ...  128.008
# 1             0.000000    0.0708    0.777   90.051  ...   90.051
# 2             0.000000    0.0616    0.934  107.088  ...  107.088
# 3             0.000000    0.0598    0.701   99.259  ...   99.259
# 4             0.000000    0.1620    0.891  110.008  ...  110.008
# ...                ...       ...      ...      ...  ...      ...
# 5083          0.000000    0.0825    0.776  133.769  ...  133.769
# 5084          0.002690    0.7090    0.746   85.126  ...   85.126
# 5085          0.000852    0.2250    0.886   98.429  ...   98.429
# 5086          0.000000    0.2920    0.716   94.798  ...   94.798
# 5087          0.000022    0.0905    0.440  124.618  ...  124.618
#
#                 type                      id  \
# 0     audio_features  0CAfXk7DXMnon4gLudAp7J
# 1     audio_features  7iL6o9tox1zgHpKUfh9vuC
# 2     audio_features  5FLctoy4mpCxLJ1QPneTOV
# 3     audio_features  0TwBtDAWpkpM3srywFVOV5
# 4     audio_features  1Je1IMUlBXcx1Fz0WE7oPT
# ...              ...                     ...
# 5083  audio_features  5jzma6gCzYtKB1DbEwFZKH
# 5084  audio_features  3KPwt1LBpt1jVSHz8GXERo
# 5085  audio_features  3MODES4TNtygekLl146Dxd
# 5086  audio_features  45s88Xopo6KvHc0PQ05aGg
# 5087  audio_features  5uvosCdMlFdTXhoazkTI5R
#
#                                        uri  \
# 0     spotify:track:0CAfXk7DXMnon4gLudAp7J
# 1     spotify:track:7iL6o9tox1zgHpKUfh9vuC
# 2     spotify:track:5FLctoy4mpCxLJ1QPneTOV
# 3     spotify:track:0TwBtDAWpkpM3srywFVOV5
# 4     spotify:track:1Je1IMUlBXcx1Fz0WE7oPT
# ...                                    ...
# 5083  spotify:track:5jzma6gCzYtKB1DbEwFZKH
# 5084  spotify:track:3KPwt1LBpt1jVSHz8GXERo
# 5085  spotify:track:3MODES4TNtygekLl146Dxd
# 5086  spotify:track:45s88Xopo6KvHc0PQ05aGg
# 5087  spotify:track:5uvosCdMlFdTXhoazkTI5R
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0CAfXk7DXMno...
# 1     https://api.spotify.com/v1/tracks/7iL6o9tox1zg...
# 2     https://api.spotify.com/v1/tracks/5FLctoy4mpCx...
# 3     https://api.spotify.com/v1/tracks/0TwBtDAWpkpM...
# 4     https://api.spotify.com/v1/tracks/1Je1IMUlBXcx...
# ...                                                 ...
# 5083  https://api.spotify.com/v1/tracks/5jzma6gCzYtK...
# 5084  https://api.spotify.com/v1/tracks/3KPwt1LBpt1j...
# 5085  https://api.spotify.com/v1/tracks/3MODES4TNtyg...
# 5086  https://api.spotify.com/v1/tracks/45s88Xopo6Kv...
# 5087  https://api.spotify.com/v1/tracks/5uvosCdMlFdT...
#
#                                            analysis_url  duration_ms.1  \
# 0     https://api.spotify.com/v1/audio-analysis/0CAf...         231400
# 1     https://api.spotify.com/v1/audio-analysis/7iL6...         193467
# 2     https://api.spotify.com/v1/audio-analysis/5FLc...         228240
# 3     https://api.spotify.com/v1/audio-analysis/0TwB...         235933
# 4     https://api.spotify.com/v1/audio-analysis/1Je1...         173027
# ...                                                 ...            ...
# 5083  https://api.spotify.com/v1/audio-analysis/5jzm...         200480
# 5084  https://api.spotify.com/v1/audio-analysis/3KPw...         313840
# 5085  https://api.spotify.com/v1/audio-analysis/3MOD...         263333
# 5086  https://api.spotify.com/v1/audio-analysis/45s8...         198867
# 5087  https://api.spotify.com/v1/audio-analysis/5uvo...         429760
#
#       time_signature       artists                             song_title
# 0                  4      Flo Rida                     Low (feat. T-Pain)
# 1                  4       50 Cent                             In Da Club
# 2                  4         Nelly                           Hot In Herre
# 3                  4       Beyoncé            Crazy In Love (feat. Jay-Z)
# 4                  4   Spice Girls                                Wannabe
# ...              ...           ...                                    ...
# 5083               4     The Clash            London Calling - Remastered
# 5084               4   Bad Company  Feel like Makin' Love - 2015 Remaster
# 5085               4  Led Zeppelin              Ramble On - 1990 Remaster
# 5086               4       The Who           My Generation - Mono Version
# 5087               4     The Doors                          Light My Fire
#
# [5088 rows x 32 columns]

# %%
## Drop the unnamed column
cluster_id.drop(columns=["Unnamed: 0"], inplace=True)
cluster_id
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.918   0.609    -5.640       0.0791       0.09280
# 1            0.899   0.713    -2.752       0.3660       0.25500
# 2            0.957   0.737    -4.880       0.1150       0.21000
# 3            0.664   0.758    -6.583       0.2100       0.00238
# 4            0.768   0.864    -6.145       0.0324       0.10100
# ...            ...     ...       ...          ...           ...
# 5083         0.651   0.801    -7.340       0.0514       0.12300
# 5084         0.543   0.529    -9.717       0.0301       0.32600
# 5085         0.468   0.607   -11.367       0.0336       0.07200
# 5086         0.299   0.787    -7.930       0.0690       0.14000
# 5087         0.413   0.725    -5.787       0.0324       0.36900
#
#       instrumentalness  liveness  valence    tempo  duration_ms  ...  tempo.1  \
# 0             0.000000    0.1390    0.304  128.008       231400  ...  128.008
# 1             0.000000    0.0708    0.777   90.051       193467  ...   90.051
# 2             0.000000    0.0616    0.934  107.088       228240  ...  107.088
# 3             0.000000    0.0598    0.701   99.259       235933  ...   99.259
# 4             0.000000    0.1620    0.891  110.008       173027  ...  110.008
# ...                ...       ...      ...      ...          ...  ...      ...
# 5083          0.000000    0.0825    0.776  133.769       200480  ...  133.769
# 5084          0.002690    0.7090    0.746   85.126       313840  ...   85.126
# 5085          0.000852    0.2250    0.886   98.429       263333  ...   98.429
# 5086          0.000000    0.2920    0.716   94.798       198867  ...   94.798
# 5087          0.000022    0.0905    0.440  124.618       429760  ...  124.618
#
#                 type                      id  \
# 0     audio_features  0CAfXk7DXMnon4gLudAp7J
# 1     audio_features  7iL6o9tox1zgHpKUfh9vuC
# 2     audio_features  5FLctoy4mpCxLJ1QPneTOV
# 3     audio_features  0TwBtDAWpkpM3srywFVOV5
# 4     audio_features  1Je1IMUlBXcx1Fz0WE7oPT
# ...              ...                     ...
# 5083  audio_features  5jzma6gCzYtKB1DbEwFZKH
# 5084  audio_features  3KPwt1LBpt1jVSHz8GXERo
# 5085  audio_features  3MODES4TNtygekLl146Dxd
# 5086  audio_features  45s88Xopo6KvHc0PQ05aGg
# 5087  audio_features  5uvosCdMlFdTXhoazkTI5R
#
#                                        uri  \
# 0     spotify:track:0CAfXk7DXMnon4gLudAp7J
# 1     spotify:track:7iL6o9tox1zgHpKUfh9vuC
# 2     spotify:track:5FLctoy4mpCxLJ1QPneTOV
# 3     spotify:track:0TwBtDAWpkpM3srywFVOV5
# 4     spotify:track:1Je1IMUlBXcx1Fz0WE7oPT
# ...                                    ...
# 5083  spotify:track:5jzma6gCzYtKB1DbEwFZKH
# 5084  spotify:track:3KPwt1LBpt1jVSHz8GXERo
# 5085  spotify:track:3MODES4TNtygekLl146Dxd
# 5086  spotify:track:45s88Xopo6KvHc0PQ05aGg
# 5087  spotify:track:5uvosCdMlFdTXhoazkTI5R
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0CAfXk7DXMno...
# 1     https://api.spotify.com/v1/tracks/7iL6o9tox1zg...
# 2     https://api.spotify.com/v1/tracks/5FLctoy4mpCx...
# 3     https://api.spotify.com/v1/tracks/0TwBtDAWpkpM...
# 4     https://api.spotify.com/v1/tracks/1Je1IMUlBXcx...
# ...                                                 ...
# 5083  https://api.spotify.com/v1/tracks/5jzma6gCzYtK...
# 5084  https://api.spotify.com/v1/tracks/3KPwt1LBpt1j...
# 5085  https://api.spotify.com/v1/tracks/3MODES4TNtyg...
# 5086  https://api.spotify.com/v1/tracks/45s88Xopo6Kv...
# 5087  https://api.spotify.com/v1/tracks/5uvosCdMlFdT...
#
#                                            analysis_url  duration_ms.1  \
# 0     https://api.spotify.com/v1/audio-analysis/0CAf...         231400
# 1     https://api.spotify.com/v1/audio-analysis/7iL6...         193467
# 2     https://api.spotify.com/v1/audio-analysis/5FLc...         228240
# 3     https://api.spotify.com/v1/audio-analysis/0TwB...         235933
# 4     https://api.spotify.com/v1/audio-analysis/1Je1...         173027
# ...                                                 ...            ...
# 5083  https://api.spotify.com/v1/audio-analysis/5jzm...         200480
# 5084  https://api.spotify.com/v1/audio-analysis/3KPw...         313840
# 5085  https://api.spotify.com/v1/audio-analysis/3MOD...         263333
# 5086  https://api.spotify.com/v1/audio-analysis/45s8...         198867
# 5087  https://api.spotify.com/v1/audio-analysis/5uvo...         429760
#
#       time_signature       artists                             song_title
# 0                  4      Flo Rida                     Low (feat. T-Pain)
# 1                  4       50 Cent                             In Da Club
# 2                  4         Nelly                           Hot In Herre
# 3                  4       Beyoncé            Crazy In Love (feat. Jay-Z)
# 4                  4   Spice Girls                                Wannabe
# ...              ...           ...                                    ...
# 5083               4     The Clash            London Calling - Remastered
# 5084               4   Bad Company  Feel like Makin' Love - 2015 Remaster
# 5085               4  Led Zeppelin              Ramble On - 1990 Remaster
# 5086               4       The Who           My Generation - Mono Version
# 5087               4     The Doors                          Light My Fire
#
# [5088 rows x 31 columns]

# %%
## Match the input song cluster with the clusters of the spotify list
match_song = cluster_id[cluster_id["cluster"] == int(input_song_cluster)]

# %%
## Return a random sample of items from an axis of object.
## Suggest a song that belongs to the same cluster
song_suggestion = match_song.sample()

# %%
## iloc gets rows (and/or columns) at integer locations.
## Sugggest the track id of the song that belongs to the same cluster
suggestion = song_suggestion["id"].iloc[0]
suggestion
# Out:
# '2Cc5z5swQrDqZiyCkZ0TnF'

# %%
## Function to get user input. It is a sum up of all the code above

def song_suggestion():
    
    song_input = input("Please enter a name of a song:")
    if song_input in hotlist.values:
        print("See other recommended song:")
        print(hotlist.sample())
    else:
        print("Unfortunately, the song is not in the hot list!")
        song_input = sp.search(q = song_input, limit = 1 , market ="GB")
        song_id = song_input["tracks"]["items"][0]["id"]
        input_song_features = sp.audio_features(song_input['tracks']['items'][0]['id'])
        input_song_features = pd.DataFrame(input_song_features)
        input_song_features_num = input_song_features._get_numeric_data()
        input_song_features_num = input_song_features_num.drop(columns=["key","mode","time_signature"])
        model = load("scaler.pickle")
        model_kmeans = load("kmeans_4.pickle")
        input_song_scaled = model.transform(input_song_features_num)
        input_song_scaled = pd.DataFrame(input_song_scaled, columns = ["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness",
                          "valence", "tempo", "duration_ms"])
       
        input_song_cluster = model_kmeans.predict(input_song_scaled)
        match_song = cluster_id[cluster_id["cluster"] == int(input_song_cluster)]
        song_suggestion = match_song.sample()
        suggestion = song_suggestion["id"].iloc[0]
        
        
    return IFrame(src="https://open.spotify.com/embed/track/"+suggestion,
               width="320",
               height="80",
               frameborder="0",
               allowtransparency="true",
               allow="encrypted-media",
                   )

# %%
song_suggestion()
# Out:
# Please enter a name of a song:crazy in love
# Unfortunately, the song is not in the hot list!
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/2fZQIJew3nkNe99s2PKzul?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
##song = sp.search(q=song_input,limit=1, market="GB")

# %%
## Get the song_id of the song_input to use in the next part of the code. (177)
song_id = song_input['tracks']['items'][0]['id']

# %%
from IPython.display import IFrame

#track_id = "1rfORa9iYmocEsnnZGMVC4"

IFrame(src="https://open.spotify.com/embed/track/"+song_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/6QyQmdvQ1ywNccYa0pwLNQ?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
