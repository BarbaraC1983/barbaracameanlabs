# %% [markdown]
# ## Health Care for All Case Study using Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50
## Install xlrd package to load Excel files
# conda install openpyxl
## conda install xlrd

# %% [markdown]
# ## EDA and Plotting

# %%
pd.read_csv("hk_df_cleaned.csv")
# Out:
#      state  gender  median_home_val  avg_fam_income  avg_household_income  \
# 0       FL    Male      1159.148591           520.0                   466
# 1       IL    Male       537.000000           473.0                   410
# 2       FL  Female       725.000000           436.0                   361
# 3       NC    Male      1159.148591           413.0                   399
# 4       FL  Female       995.000000           348.0                   316
# ...    ...     ...              ...             ...                   ...
# 4015    FL  Female       742.000000           470.0                   450
# 4016    FL    Male       599.000000           423.0                   200
# 4017    ND    Male       593.000000           299.0                   274
# 4018    WI       U       564.000000           397.0                   295
# 4019    MI    Male       651.000000           505.0                   455
#
#       med_fam_income  median_household_income  hvp1  per_capita_income  pobc2  \
# 0              430.0                      392     7            21975.0     16
# 1              415.0                      365     0            19387.0     89
# 2              340.0                      301     3            18837.0     17
# 3              407.0                      401     7            14014.0     74
# 4              280.0                      252     0            17991.0      6
# ...              ...                      ...   ...                ...    ...
# 4015           424.0                      396     0            15356.0     37
# 4016           406.0                      100     4            11670.0     27
# 4017           298.0                      258     0            10186.0     70
# 4018           386.0                      217     0            12315.0     96
# 4019           451.0                      431     0            14845.0     77
#
#       avggift domain  target_d
# 0          28     C2     100.0
# 1           5     T2       7.0
# 2           4     C2       5.0
# 3          27     T2      38.0
# 4           6     C2       5.0
# ...       ...    ...       ...
# 4015       14     S2      50.0
# 4016        9     C1      10.0
# 4017        5     S2       5.0
# 4018       11     T2      14.0
# 4019        7     S2       9.0
#
# [4020 rows x 13 columns]

# %%
hk_df.columns
# Out:
# Index(['state', 'gender', 'median_home_val', 'avg_fam_income',
#        'avg_household_income', 'med_fam_income', 'median_household_income',
#        'hvp1', 'per_capita_income', 'pobc2', 'avggift', 'domain', 'target_d'],
#       dtype='object')

# %%
plt.scatter(x=hk_df['med_fam_income'], y=hk_df['avg_household_income'])
plt.show()

# %%
sns.pairplot(hk_df)

# %%
hk_df.hist(figsize=(12,12))
# Out:
# array([[<AxesSubplot:title={'center':'median_home_val'}>,
#         <AxesSubplot:title={'center':'avg_fam_income'}>,
#         <AxesSubplot:title={'center':'avg_household_income'}>],
#        [<AxesSubplot:title={'center':'med_fam_income'}>,
#         <AxesSubplot:title={'center':'median_household_income'}>,
#         <AxesSubplot:title={'center':'hvp1'}>],
#        [<AxesSubplot:title={'center':'per_capita_income'}>,
#         <AxesSubplot:title={'center':'pobc2'}>,
#         <AxesSubplot:title={'center':'avggift'}>],
#        [<AxesSubplot:title={'center':'target_d'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.displot((hk_df['median_home_val']), bins=20)

# %%
hk_df
# Out:
#      state  gender  median_home_val  avg_fam_income  avg_household_income  \
# 0       FL    Male      1159.148591           520.0                   466
# 1       IL    Male       537.000000           473.0                   410
# 2       FL  Female       725.000000           436.0                   361
# 3       NC    Male      1159.148591           413.0                   399
# 4       FL  Female       995.000000           348.0                   316
# ...    ...     ...              ...             ...                   ...
# 1001    FL  Female       742.000000           470.0                   450
# 1002    FL    Male       599.000000           423.0                   200
# 1003    ND    Male       593.000000           299.0                   274
# 1004    WI       U       564.000000           397.0                   295
# 1005    MI    Male       651.000000           505.0                   455
#
#       med_fam_income  median_household_income  hvp1  per_capita_income  pobc2  \
# 0              430.0                      392     7            21975.0     16
# 1              415.0                      365     0            19387.0     89
# 2              340.0                      301     3            18837.0     17
# 3              407.0                      401     7            14014.0     74
# 4              280.0                      252     0            17991.0      6
# ...              ...                      ...   ...                ...    ...
# 1001           424.0                      396     0            15356.0     37
# 1002           406.0                      100     4            11670.0     27
# 1003           298.0                      258     0            10186.0     70
# 1004           386.0                      217     0            12315.0     96
# 1005           451.0                      431     0            14845.0     77
#
#       avggift domain  target_d
# 0          28     C2     100.0
# 1           5     T2       7.0
# 2           4     C2       5.0
# 3          27     T2      38.0
# 4           6     C2       5.0
# ...       ...    ...       ...
# 1001       14     S2      50.0
# 1002        9     C1      10.0
# 1003        5     S2       5.0
# 1004       11     T2      14.0
# 1005        7     S2       9.0
#
# [4020 rows x 13 columns]

# %% [raw]
# median_home_val_boxcox=boxcox(hk_df["pobc2"],lmbda=0.04)
# median_home_val_boxcox
# sns.displot(median_home_val_boxcox)

# %% [markdown]
# <b>Power Transformer

# %%
pt = PowerTransformer()
med_home_val_transformed=pt.fit_transform(hk_df['median_home_val'].to_numpy().reshape(-1,1))
sns.displot(med_home_val_transformed)

# %%
##crud
hk_df["med_home_val_transformed"]= med_home_val_transformed
hk_df.drop(["median_home_val"],axis=1,inplace=True)

# %%
hk_df
# Out:
#      state  gender  avg_fam_income  avg_household_income  med_fam_income  \
# 0       FL    Male           520.0                   466           430.0
# 1       IL    Male           473.0                   410           415.0
# 2       FL  Female           436.0                   361           340.0
# 3       NC    Male           413.0                   399           407.0
# 4       FL  Female           348.0                   316           280.0
# ...    ...     ...             ...                   ...             ...
# 1001    FL  Female           470.0                   450           424.0
# 1002    FL    Male           423.0                   200           406.0
# 1003    ND    Male           299.0                   274           298.0
# 1004    WI       U           397.0                   295           386.0
# 1005    MI    Male           505.0                   455           451.0
#
#       median_household_income  hvp1  per_capita_income  pobc2  avggift domain  \
# 0                         392     7            21975.0     16       28     C2
# 1                         365     0            19387.0     89        5     T2
# 2                         301     3            18837.0     17        4     C2
# 3                         401     7            14014.0     74       27     T2
# 4                         252     0            17991.0      6        6     C2
# ...                       ...   ...                ...    ...      ...    ...
# 1001                      396     0            15356.0     37       14     S2
# 1002                      100     4            11670.0     27        9     C1
# 1003                      258     0            10186.0     70        5     S2
# 1004                      217     0            12315.0     96       11     T2
# 1005                      431     0            14845.0     77        7     S2
#
#       target_d  med_home_val_transformed
# 0        100.0                  0.294846
# 1          7.0                 -0.636833
# 2          5.0                 -0.294111
# 3         38.0                  0.294846
# 4          5.0                  0.095725
# ...        ...                       ...
# 1001      50.0                 -0.266584
# 1002      10.0                 -0.514993
# 1003       5.0                 -0.526356
# 1004      14.0                 -0.582535
# 1005       9.0                 -0.419946
#
# [4020 rows x 13 columns]

# %%
hk_df.corr()
# Out:
#                           avg_fam_income     pobc2   avggift  target_d  \
# avg_fam_income                  1.000000 -0.188200  0.133512  0.131467
# pobc2                          -0.188200  1.000000 -0.076623 -0.073461
# avggift                         0.133512 -0.076623  1.000000  0.487661
# target_d                        0.131467 -0.073461  0.487661  1.000000
# med_home_val_transformed        0.774526 -0.290786  0.132895  0.109231
#
#                           med_home_val_transformed
# avg_fam_income                            0.774526
# pobc2                                    -0.290786
# avggift                                   0.132895
# target_d                                  0.109231
# med_home_val_transformed                  1.000000

# %%
corr
# Out:
#                           avg_fam_income  avg_household_income  \
# avg_fam_income                  1.000000              0.971836
# avg_household_income            0.971836              1.000000
# med_fam_income                  0.971506              0.953457
# median_household_income         0.928871              0.974811
# hvp1                            0.655683              0.647076
# per_capita_income               0.868590              0.827779
# pobc2                          -0.188200             -0.177718
# avggift                         0.133512              0.126355
# target_d                        0.131467              0.122328
# med_home_val_transformed        0.774526              0.766023
#
#                           med_fam_income  median_household_income      hvp1  \
# avg_fam_income                  0.971506                 0.928871  0.655683
# avg_household_income            0.953457                 0.974811  0.647076
# med_fam_income                  1.000000                 0.951152  0.636358
# median_household_income         0.951152                 1.000000  0.610842
# hvp1                            0.636358                 0.610842  1.000000
# per_capita_income               0.874875                 0.805333  0.627228
# pobc2                          -0.162568                -0.149607 -0.260485
# avggift                         0.137010                 0.121198  0.127827
# target_d                        0.129900                 0.113411  0.103891
# med_home_val_transformed        0.743238                 0.719779  0.836741
#
#                           per_capita_income     pobc2   avggift  target_d  \
# avg_fam_income                     0.868590 -0.188200  0.133512  0.131467
# avg_household_income               0.827779 -0.177718  0.126355  0.122328
# med_fam_income                     0.874875 -0.162568  0.137010  0.129900
# median_household_income            0.805333 -0.149607  0.121198  0.113411
# hvp1                               0.627228 -0.260485  0.127827  0.103891
# per_capita_income                  1.000000 -0.248571  0.142640  0.138107
# pobc2                             -0.248571  1.000000 -0.076623 -0.073461
# avggift                            0.142640 -0.076623  1.000000  0.487661
# target_d                           0.138107 -0.073461  0.487661  1.000000
# med_home_val_transformed           0.693802 -0.290786  0.132895  0.109231
#
#                           med_home_val_transformed
# avg_fam_income                            0.774526
# avg_household_income                      0.766023
# med_fam_income                            0.743238
# median_household_income                   0.719779
# hvp1                                      0.836741
# per_capita_income                         0.693802
# pobc2                                    -0.290786
# avggift                                   0.132895
# target_d                                  0.109231
# med_home_val_transformed                  1.000000

# %%
corr = hk_df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(9, 7))
    ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %% [markdown]
# ### Highly Correlated Columns

# %%
corr_matrix=hk_df.corr().abs()
upper_triangle=corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(bool))
[column for column in upper_triangle.columns if any(upper_triangle[column] > 0.80)]
# Out:
# ['avg_household_income',
#  'med_fam_income',
#  'median_household_income',
#  'per_capita_income',
#  'med_home_val_transformed']

# %% [markdown]
# ### dropping highly correlated features

# %%
hk_df.drop(["per_capita_income","hvp1","avg_household_income","median_household_income","med_fam_income"],axis=1,inplace=True)

# %%
hk_df
# Out:
#      state  gender  avg_fam_income  pobc2  avggift domain  target_d  \
# 0       FL    Male           520.0     16       28     C2     100.0
# 1       IL    Male           473.0     89        5     T2       7.0
# 2       FL  Female           436.0     17        4     C2       5.0
# 3       NC    Male           413.0     74       27     T2      38.0
# 4       FL  Female           348.0      6        6     C2       5.0
# ...    ...     ...             ...    ...      ...    ...       ...
# 1001    FL  Female           470.0     37       14     S2      50.0
# 1002    FL    Male           423.0     27        9     C1      10.0
# 1003    ND    Male           299.0     70        5     S2       5.0
# 1004    WI       U           397.0     96       11     T2      14.0
# 1005    MI    Male           505.0     77        7     S2       9.0
#
#       med_home_val_transformed
# 0                     0.294846
# 1                    -0.636833
# 2                    -0.294111
# 3                     0.294846
# 4                     0.095725
# ...                        ...
# 1001                 -0.266584
# 1002                 -0.514993
# 1003                 -0.526356
# 1004                 -0.582535
# 1005                 -0.419946
#
# [4020 rows x 8 columns]
